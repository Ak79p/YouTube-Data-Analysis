# %% [markdown]
# **Problem statement**
#
# Videos are a fast growing medium where people communicate, share knowledge, showcase skills etc. YouTube is one of the biggest platforms which hosts videos. The YouTube platform hosts content from many different professions/arts/ cultures across the world.
#
# People can express their opinion about the video in the form of likes, dislikes, comments which are features provided by the YouTube platform which provides the information on the sentiment about the video.
#
# The assignment involves the steps on programmatic data extraction from YouTube on which analysis can be conducted to understand various attributes related to a video.

# %% [markdown]
# **Steps performed**

# %% [markdown]
# ### 1. Connect to the Youtube API using a Python client

# %% [markdown]
# #### a) Create a YouTube API key

# %% [markdown]
# In the Google Cloud Console, created a new project. Enabled the YouTube Data API for the project and generated credentials (API key) to establish a connection.

# %% [markdown]
# #### b) Install the Google API python client

# %% [markdown]
# Google API python client installed in Windows by entering the below command in Command prompt:
#
# 'pip install --upgrade google-api-python-client'

# %%
from googleapiclient.discovery import build

key = '<Provie your API key>'
api_service_name = 'youtube'
api_version = 'v3'

youtube = build(api_service_name, api_version, developerKey=key)

request = youtube.search().list(
        part='snippet',
        maxResults=5,
        q='avatar movie'
    )
response = request.execute()
if response:
    print('Connection to YouTube API successful.')
else:
    print('Failed to connect to YouTube API.')
# Out:
# Connection to YouTube API successful.

# %% [markdown]
# ### 2. Search and extract the data

# %% [markdown]
# #### a) Search videos related to the query string  “avatar movie”

# %%
request = youtube.search().list(
        part='snippet',
        maxResults=1,
        q='avatar movie'
    )
response = request.execute()
video = response['items'][0]

#ID
videoId = video['id']['videoId']
print('ID: ',videoId)

#Channel ID
channelId = video['snippet']['channelId']
print("--Snippet--")
print('Channel ID: ',channelId)

#Video Description
description = video['snippet']['description']
print('Video Description: ',description)

# Channel Title
channelTitle = video['snippet']['channelTitle']
print('Channel Title: ',channelTitle)

#Video Title
title = video['snippet']['title']
print('Video Title: ',title)
# Out:
# ID:  RNj2cH5yjNA
# --Snippet--
# Channel ID:  UC0A86RKLCqTEUna3hPlEpzg
# Video Description:  AVATAR Full Movie 2024: Pandora World | Superhero FXL Action Movies 2024 in English (Game Movie). Best Action Game ...
# Channel Title:  Superhero FXL Games
# Video Title:  AVATAR Full Movie 2024: Pandora World | Superhero FXL Action Movies 2024 in English (Game Movie)

# %% [markdown]
# #### b) Provide the following statistics for query string “avatar movie” of top 50 videos sorted by relevance in the US region

# %%
import pandas as pd

# request for “avatar movie” of top 50 videos sorted by relevance in the US region
request = youtube.search().list(
        q='avatar movie',
        part='snippet',
        maxResults=50,
        regionCode='US',
        order='relevance',
        type='video'
    )
response = request.execute()

videoID = [item['id']['videoId'] for item in response['items']]

title,no_of_views,no_of_likes,no_of_comments = [],[],[],[]
for videoId in videoID:
        request = youtube.videos().list(
                part='snippet,contentDetails,statistics',
                id=videoId
                )
        response = request.execute()
        title.append(response['items'][0]['snippet'].get('title', 'NA'))
        no_of_views.append(response['items'][0]['statistics'].get('viewCount', 'NA'))
        no_of_likes.append(response['items'][0]['statistics'].get('likeCount', 'NA'))
        no_of_comments.append(response['items'][0]['statistics'].get('commentCount', 'NA'))
 

# Export to csv file
df = pd.DataFrame({
    'Video ID': videoID,
    'Title':title,
    'no_of_views': no_of_views,
    'no_of_likes':no_of_likes,
    'no_of_comments':no_of_comments
})
df.to_csv('youtube_video_stats.csv', index=False)

# %% [markdown]
# ### 3. Analyze the exported data obtained in 2.b and carry out the following tasks

# %% [markdown]
# #### a) Sort the data 2.b  by top 10 comments in descending order and consider the video IDs and Titles of top 10 videos which have highest comments.

# %%
df['no_of_comments'] = df['no_of_comments'].astype(int)
sorted_df = df.sort_values(by='no_of_comments',ascending=False)
top_10_video_ids_and_titles = sorted_df.head(10)[['Video ID', 'Title','no_of_comments']]
top_10_video_ids_and_titles
# Out:
#        Video ID                                              Title  \
# 2   d9MyW72ELq0        Avatar: The Way of Water | Official Trailer
# 20  a8Gx8wiNbs8  Avatar: The Way of Water | Official Teaser Tra...
# 28  bDHD1ueL4a4  The Weeknd - Nothing Is Lost (You Give Me Stre...
# 21  RGx8rYbRVR4  Why People Hate Avatar: A Lesson In Lazy Comme...
# 38  doDrnJkgf-s  Zoe Saldana Emotional Avatar Scene Behind The ...
# 43  f5Zx8iPek5I  Avatar 3 Will Introduce The Dark Side🔥 Of Na'v...
# 37  mRrKdgpZ6kE     AGAINST JAKE..!??😲😲 | AVATAR 3 #shorts #avatar
# 49  PLtgIILX7E8  AVATAR Full Movie 2023: Fallen Kingdom | Super...
# 41  X8SVkfbt8cs                           Avatar: The Way of Water
# 32  oFErWcXJLdw            TRAINING TO BE IN THE NEXT AVATAR MOVIE
#
#     no_of_comments
# 2            42699
# 20           28934
# 28            9731
# 21            5202
# 38            5099
# 43            4051
# 37            2300
# 49            2151
# 41            1833
# 32            1763

# %% [markdown]
# #### b) Use a suitable method to retrieve comments of those top 10 videos from 3.a.

# %%
from pprint import pprint


def retrieve_comments(df):
    # for loop to retrieve top 10 comments for each video
    top_10_video_comments={}
    for id in df['Video ID']:
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=id,
            maxResults=10
        )
        response = request.execute()

        comments = {
            'etag': response['etag'],
            'items': []
        }
        for item in response['items']:
            comment_info={
                'id':item['id'],
                'kind':item['kind'],
                'snippet':{
                    'textDisplay':item['snippet']['topLevelComment']['snippet']['textDisplay']
                }
            }
            comments['items'].append(comment_info)
        top_10_video_comments[f'{id}_comments']=comments
    return top_10_video_comments

top_video_comments = retrieve_comments(top_10_video_ids_and_titles)

pprint(top_video_comments)
# Out:
# {'PLtgIILX7E8_comments': {'etag': '0lOIoDKPlwnqEUc19lCcRXWvKyI',
#                           'items': [{'id': 'UgzQPg-rwH_W7eyhxQx4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'The subtitles '
#                                                                 'are available '
#                                                                 'in English, '
#                                                                 'Hindi, '
#                                                                 'Portuguese, '
#                                                                 'French, '
#                                                                 'Spanish, '
#                                                                 'German, '
#                                                                 'Indonesian, '
#                                                                 'and Thai. '
#                                                                 'Other '
#                                                                 'languages can '
#                                                                 'be selected '
#                                                                 'using '
#                                                                 'YouTube&#39;s '
#                                                                 'automatic '
#                                                                 'translation.\r'
#                                                                 '<br>If you '
#                                                                 'enjoyed the '
#                                                                 'video, '
#                                                                 'don&#39;t '
#                                                                 'forget to '
#                                                                 'subscribe for '
#                                                                 'more '
#                                                                 'content.\r'
#                                                                 '<br>Thank you '
#                                                                 'for '
#                                                                 'watching.'}},
#                                     {'id': 'UgzTvMVNrfvAzPp1QQ14AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'Traduire en '
#                                                                 'français'}},
#                                     {'id': 'Ugy9oFrvmnFGCLWfNhx4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'Good movie'}},
#                                     {'id': 'UgxNgh0nuNoYjXTNrad4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'Disparar una '
#                                                                 'arma es '
#                                                                 'muerte y '
#                                                                 'destrucción y '
#                                                                 'para mi '
#                                                                 'opinión no es '
#                                                                 'apta para '
#                                                                 'niños no es '
#                                                                 'de mi '
#                                                                 'gusto.'}},
#                                     {'id': 'Ugw-ngenqyOzaVsy1MF4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'Soy de las '
#                                                                 'personas que '
#                                                                 'no '
#                                                                 'compartimos '
#                                                                 'ver tanta '
#                                                                 'destrucción, '
#                                                                 'la vida '
#                                                                 'salvaje la '
#                                                                 'naturaleza, '
#                                                                 'para mi '
#                                                                 'detonar una '
#                                                                 'arma es '
#                                                                 'traducción.'}},
#                                     {'id': 'UgwRjwSTiRoXQVQewNd4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': '❤❤❤❤❤'}},
#                                     {'id': 'Ugx0fGp8A0-jtIZy1Al4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': '<a '
#                                                                 'href="https://www.youtube.com/watch?v=PLtgIILX7E8&amp;t=16">0:16</a> '
#                                                                 '<a '
#                                                                 'href="https://www.youtube.com/watch?v=PLtgIILX7E8&amp;t=17">0:17</a> '
#                                                                 '😅'}},
#                                     {'id': 'UgxQFaAT8NdX4FVU5vt4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': '<i>huh</i>'}},
#                                     {'id': 'UgxKEdMn0g7rc1VDAR14AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': '🤗🤗🤗😇😇😇😇🤑🤑🤑🤑🤑🤑😻😻💘💝'}},
#                                     {'id': 'Ugw7ivMqHT1CyR2FZnh4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'Природа '
#                                                                 'красивая '
#                                                                 'необычный '
#                                                                 'фильм ❤'}}]},
#  'RGx8rYbRVR4_comments': {'etag': 'X1KEwcs4nXzwUeNP85mg639_lxs',
#                           'items': [{'id': 'UgyGn8e7SsOO91xPX0V4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'If you want '
#                                                                 'to see that '
#                                                                 'extra video '
#                                                                 'from me on '
#                                                                 'writing '
#                                                                 'exposition, '
#                                                                 'you can watch '
#                                                                 'it here: <a '
#                                                                 'href="https://nebula.tv/videos/the-closer-look-how-to-write-great-exposition">https://nebula.tv/videos/the-closer-look-how-to-write-great-exposition</a><br><br>I '
#                                                                 'break down a '
#                                                                 'lot of '
#                                                                 'examples from '
#                                                                 'Avatar, to '
#                                                                 'Revenge of '
#                                                                 'the Sith, and '
#                                                                 'if you like '
#                                                                 'my normal '
#                                                                 'content, '
#                                                                 'you&#39;ll '
#                                                                 'definitely '
#                                                                 'enjoy this '
#                                                                 'one!<br><br>Have '
#                                                                 'a great '
#                                                                 'day,<br>- '
#                                                                 'Henry'}},
#                                     {'id': 'UgzJIHE9rnycT5mnHQl4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': '<a '
#                                                                 'href="https://www.youtube.com/watch?v=RGx8rYbRVR4&amp;t=1430">23:50</a> '
#                                                                 'no, we '
#                                                                 'don&#39;t '
#                                                                 'need oil. '
#                                                                 'Fuck off'}},
#                                     {'id': 'UgwDKPAP2mNEfwr00op4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'This video '
#                                                                 'helped me '
#                                                                 'realize I '
#                                                                 'don&#39;t '
#                                                                 'hate Avater '
#                                                                 'per se, I '
#                                                                 'just think '
#                                                                 'it&#39;s '
#                                                                 'schlock and I '
#                                                                 'resent '
#                                                                 'it&#39;s '
#                                                                 'popularity'}},
#                                     {'id': 'UgwAtqqj0WNnqHkxtGN4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'I dislike '
#                                                                 'Avatar '
#                                                                 'because i '
#                                                                 'tried to '
#                                                                 'watch it 3 '
#                                                                 'times and '
#                                                                 'fell asleep '
#                                                                 'each '
#                                                                 'time.<br><br>The '
#                                                                 '4th time, i '
#                                                                 'forced myself '
#                                                                 'to be awake, '
#                                                                 'and the plot '
#                                                                 'just '
#                                                                 'doesn&#39;t '
#                                                                 'do it for '
#                                                                 'me.<br><br>It&#39;s '
#                                                                 'a very pretty '
#                                                                 'film '
#                                                                 'visually. But '
#                                                                 'after 20 '
#                                                                 'minutes, '
#                                                                 'where is the '
#                                                                 'plot?'}},
#                                     {'id': 'UgwRWo5SaPiyL9HSLSN4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'See I liked '
#                                                                 'the first '
#                                                                 'part. I felt '
#                                                                 'ecstatic. '
#                                                                 'Because I was '
#                                                                 'so young and '
#                                                                 'I saw all '
#                                                                 'those '
#                                                                 'beautiful '
#                                                                 'things and '
#                                                                 'the '
#                                                                 'technology '
#                                                                 'for the first '
#                                                                 'time. Also '
#                                                                 'the small '
#                                                                 'attention to '
#                                                                 'details about '
#                                                                 'the Navi hair '
#                                                                 'and it being '
#                                                                 'connected to '
#                                                                 'the horse '
#                                                                 'just like a '
#                                                                 'usb was '
#                                                                 'amazing to '
#                                                                 'me.<br>But I '
#                                                                 'admit I kinda '
#                                                                 'slept in the '
#                                                                 'second movie '
#                                                                 '😂'}},
#                                     {'id': 'UgxvAKbJAlLmgXnQP3J4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'I don&#39;t '
#                                                                 'disagree with '
#                                                                 'most of your '
#                                                                 'points, '
#                                                                 'except that '
#                                                                 'you seem to '
#                                                                 'ignore that '
#                                                                 'these are two '
#                                                                 'of the most '
#                                                                 'popular films '
#                                                                 'ever. Cameron '
#                                                                 'wants to have '
#                                                                 'a political '
#                                                                 'influence on '
#                                                                 'his audience '
#                                                                 'and can you '
#                                                                 'be sure that '
#                                                                 'these films '
#                                                                 'would be more '
#                                                                 'effective for '
#                                                                 'the '
#                                                                 'world&#39;s '
#                                                                 'biggest '
#                                                                 'audience if '
#                                                                 'that were '
#                                                                 'more '
#                                                                 'dramatically '
#                                                                 'complex? Yes '
#                                                                 'they are '
#                                                                 'propaganda, '
#                                                                 'as are many '
#                                                                 'films, but '
#                                                                 'propaganda '
#                                                                 'for a good '
#                                                                 'cause is fine '
#                                                                 'with me, as '
#                                                                 'much as a '
#                                                                 'political '
#                                                                 'advertisement '
#                                                                 'would be. '
#                                                                 'Also I '
#                                                                 'challenge '
#                                                                 'your '
#                                                                 'assumption '
#                                                                 'that the Navi '
#                                                                 'represent '
#                                                                 '&#39;our '
#                                                                 'ancestors&#39;. '
#                                                                 'There are '
#                                                                 'people living '
#                                                                 'today in '
#                                                                 'cultures '
#                                                                 'today that '
#                                                                 'resemble the '
#                                                                 'Navi way of '
#                                                                 'life, but '
#                                                                 'more than '
#                                                                 'that could it '
#                                                                 'not be that '
#                                                                 'they are to '
#                                                                 'represent a '
#                                                                 'utopian way '
#                                                                 'of life? '
#                                                                 'Right there '
#                                                                 'is a strawman '
#                                                                 'fallacy of '
#                                                                 'your own. You '
#                                                                 'and I would '
#                                                                 'prefer these '
#                                                                 'films more if '
#                                                                 'they were '
#                                                                 'more '
#                                                                 'dramatically '
#                                                                 'sophisticated '
#                                                                 'but would '
#                                                                 'they then be '
#                                                                 'actually '
#                                                                 'better at '
#                                                                 'fulfilling '
#                                                                 'their '
#                                                                 'intended '
#                                                                 'purpose?'}},
#                                     {'id': 'UgxJyHqKospD5EhW3e14AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'a movie '
#                                                                 'doesn&#39;t '
#                                                                 'need dialogue '
#                                                                 'to show the '
#                                                                 'impact of '
#                                                                 'thos story, i '
#                                                                 'personally '
#                                                                 'belive that '
#                                                                 'thos movie '
#                                                                 'hints to the '
#                                                                 'native '
#                                                                 'americans and '
#                                                                 'how the '
#                                                                 'americans '
#                                                                 'killed them, '
#                                                                 'and took '
#                                                                 'their home, '
#                                                                 'desecrating '
#                                                                 'ritual sites '
#                                                                 'and '
#                                                                 'displacing '
#                                                                 'them to make '
#                                                                 'more room for '
#                                                                 'them, btw im '
#                                                                 'not some woke '
#                                                                 'guy, the '
#                                                                 'hints are j '
#                                                                 'like there'}},
#                                     {'id': 'UgwerceG3qa9_2GwIwB4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'Humanity was '
#                                                                 'meant to rule '
#                                                                 'the stars. '
#                                                                 'RDA First! '
#                                                                 'Humanity '
#                                                                 'First!'}},
#                                     {'id': 'Ugw_qdTj7FfjlEC6AKx4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'NO you get it '
#                                                                 'wrong. There '
#                                                                 'is no need '
#                                                                 'for a 30min '
#                                                                 'analysis.<br> '
#                                                                 'The first one '
#                                                                 'was '
#                                                                 'Pocahontas or '
#                                                                 'Winnetou but '
#                                                                 'in Blue. We '
#                                                                 'know the '
#                                                                 'story so its '
#                                                                 'boring and '
#                                                                 'lazy.<br>The '
#                                                                 '2nd copied '
#                                                                 'the '
#                                                                 'storybeats of '
#                                                                 'the first one '
#                                                                 '(which was '
#                                                                 'already a '
#                                                                 'copy) so its '
#                                                                 'even more '
#                                                                 'boring and '
#                                                                 'lazy.'}},
#                                     {'id': 'UgwOjFBmUgKYq6ZMXHV4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'I think the '
#                                                                 'simplest way '
#                                                                 'to describe '
#                                                                 'what is bad '
#                                                                 'about the '
#                                                                 'movies, is '
#                                                                 'that '
#                                                                 'everything '
#                                                                 'feels like a '
#                                                                 'caricature of '
#                                                                 'itself. The '
#                                                                 'villain is '
#                                                                 'villainy cus '
#                                                                 'they&#39;re a '
#                                                                 'villain. The '
#                                                                 'good guy is '
#                                                                 'good because '
#                                                                 'they&#39;re '
#                                                                 'the good guy. '
#                                                                 'The dialogie '
#                                                                 'is indeed a '
#                                                                 'dialogue. The '
#                                                                 'plot is very '
#                                                                 'in-your-face, '
#                                                                 'because it '
#                                                                 'has to make '
#                                                                 'sure you '
#                                                                 'understand '
#                                                                 'that it is, '
#                                                                 'indeed, a '
#                                                                 'plot. The '
#                                                                 'messaging '
#                                                                 'messages very '
#                                                                 'directly.<br><br>There '
#                                                                 'is no '
#                                                                 'subtlety, no '
#                                                                 'nuance. Every '
#                                                                 'aspect sees '
#                                                                 'what it has '
#                                                                 'to '
#                                                                 'communicate, '
#                                                                 'and just '
#                                                                 'brunt force '
#                                                                 'straightlines '
#                                                                 'towards it '
#                                                                 '-whereas had '
#                                                                 'it been '
#                                                                 'naturally '
#                                                                 'flowing, it '
#                                                                 'would dip and '
#                                                                 'bend and '
#                                                                 'navigate its '
#                                                                 'way through '
#                                                                 'in a manner '
#                                                                 'that feels '
#                                                                 'genuine and '
#                                                                 'nuanced, '
#                                                                 'instead of '
#                                                                 'just paving a '
#                                                                 'straight path '
#                                                                 'with '
#                                                                 'sledgehammers '
#                                                                 'and '
#                                                                 'dynamite.<br><br>---<br>This '
#                                                                 'is not to say '
#                                                                 'there '
#                                                                 'aren&#39;t '
#                                                                 'great aspects '
#                                                                 'of the '
#                                                                 'movies. This, '
#                                                                 'too, is '
#                                                                 'nuanced. But '
#                                                                 'I will never '
#                                                                 'truly '
#                                                                 'appreciate '
#                                                                 'them in full, '
#                                                                 'because not '
#                                                                 'all of their '
#                                                                 'entirety is '
#                                                                 'appreciation '
#                                                                 'worthy.<br><br>The '
#                                                                 'Avatar movies '
#                                                                 'make me feel '
#                                                                 'like I would '
#                                                                 'enjoy them '
#                                                                 'more if I was '
#                                                                 'less '
#                                                                 'intelligent.'}}]},
#  'X8SVkfbt8cs_comments': {'etag': 'KCyEOuztuMxkrwGrkNT34VVZ1bs',
#                           'items': [{'id': 'Ugz_gdzH1n66UYmVmAd4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'Please, '
#                                                                 '@James '
#                                                                 'Cameron; '
#                                                                 'don’t make us '
#                                                                 'wait <a '
#                                                                 'href="https://www.youtube.com/watch?v=X8SVkfbt8cs&amp;t=11231">3:07:11</a>  '
#                                                                 '14 years. We '
#                                                                 'need another '
#                                                                 'one now!!! '
#                                                                 '🎉❤'}},
#                                     {'id': 'UgzA05qPjXC3D8ceLrh4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'i promise im '
#                                                                 'not crying.. '
#                                                                 'but they know '
#                                                                 'what they did '
#                                                                 'playing the '
#                                                                 'weeknd at the '
#                                                                 'end'}},
#                                     {'id': 'UgzOASXeNClLtEzycql4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'I LOVE '
#                                                                 'AVATARRR ❤'}},
#                                     {'id': 'UgzKX7_To5UldfuZ5VN4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'What a great '
#                                                                 'movie! I '
#                                                                 'think I like '
#                                                                 'it as much as '
#                                                                 'if not more '
#                                                                 'than the '
#                                                                 'first.'}},
#                                     {'id': 'UgzvKnxoo232YdAHjRh4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'Very '
#                                                                 'beautiful '
#                                                                 'movie bravo'}},
#                                     {'id': 'UgzViGJnRh1-3M1PKfh4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'Nowhere near '
#                                                                 'as good as '
#                                                                 'the first '
#                                                                 'one. Like so '
#                                                                 'many sequels, '
#                                                                 'let&#39;s '
#                                                                 'make the '
#                                                                 'sequel about '
#                                                                 'mostly kids '
#                                                                 'and a family '
#                                                                 'cause '
#                                                                 'that&#39;ll '
#                                                                 'be different '
#                                                                 'than the '
#                                                                 'original.'}},
#                                     {'id': 'UgzyDniQxg55FdIQTyR4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'I prefer the '
#                                                                 'band'}},
#                                     {'id': 'Ugxc19AvQYSVZ0HGIxB4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'James '
#                                                                 'Cameron,  the '
#                                                                 'greatest '
#                                                                 'pioneer '
#                                                                 '<br>No budget '
#                                                                 'too steep, no '
#                                                                 'sea too deep '
#                                                                 '(who&#39;s '
#                                                                 'that it&#39;s '
#                                                                 'him, James '
#                                                                 'Cameron) 🎶🎵'}},
#                                     {'id': 'UgytSz6IbM-3Vm_dYlt4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'I absolutely '
#                                                                 'LOVE this '
#                                                                 'movie but my '
#                                                                 'second '
#                                                                 'favorite ship '
#                                                                 'being Kiri '
#                                                                 'and Spider '
#                                                                 'and wondering '
#                                                                 'how they are '
#                                                                 'going to do '
#                                                                 'that '
#                                                                 'considering '
#                                                                 'Kiri’s '
#                                                                 'actress is '
#                                                                 'Sigourney '
#                                                                 'Weaver and '
#                                                                 'Spider’s is '
#                                                                 'Jack '
#                                                                 'Champion. '
#                                                                 'HUGE age '
#                                                                 'difference.'}},
#                                     {'id': 'Ugz_bvcez83Wx7m89x54AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'I love '
#                                                                 'everything '
#                                                                 'Avatar. If '
#                                                                 'Humanity '
#                                                                 'doesn&#39;t '
#                                                                 'learn, '
#                                                                 'extinction is '
#                                                                 'the only '
#                                                                 'cure. 8 '
#                                                                 'billion being '
#                                                                 'enslaved by '
#                                                                 'the .00001%. '
#                                                                 'What a joke. '
#                                                                 'Time to put '
#                                                                 'the corrupt '
#                                                                 'politicians, '
#                                                                 'bankers, '
#                                                                 'Ceos, etc '
#                                                                 'etc. In their '
#                                                                 'place'}}]},
#  'a8Gx8wiNbs8_comments': {'etag': 'nQl2UQ3fdXroXEwDq8lSgqjjdxc',
#                           'items': [{'id': 'UgzNcpiqQ-arBC3GpPp4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'Still the '
#                                                                 'best teaser '
#                                                                 'trailer for a '
#                                                                 'film'}},
#                                     {'id': 'UgzRaVIFjNcbI381nit4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'Its '
#                                                                 'Imagination '
#                                                                 'For Us But '
#                                                                 'Not For James '
#                                                                 'Cameron'}},
#                                     {'id': 'Ugy5tdEZHbaVRyI_LTF4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': '👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍'}},
#                                     {'id': 'UgwIZQH66x1RbsZuwTZ4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': '2y 😦'}},
#                                     {'id': 'UgyTB8GAE_S0GZ3gJmt4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'Years later, '
#                                                                 'this one '
#                                                                 'still gives '
#                                                                 'me chills.'}},
#                                     {'id': 'UgxglAOleMPiUMgfH2d4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'Avatar The '
#                                                                 'Way of Water '
#                                                                 'was '
#                                                                 'absolutely '
#                                                                 'phenomenal, '
#                                                                 '13 years '
#                                                                 'after the '
#                                                                 'first movie, '
#                                                                 'James Cameron '
#                                                                 'perfectly '
#                                                                 'recaptured '
#                                                                 'the magic and '
#                                                                 'what made the '
#                                                                 'first Avatar '
#                                                                 'so special, '
#                                                                 'so much added '
#                                                                 'world '
#                                                                 'building, the '
#                                                                 'amazing '
#                                                                 'visuals, '
#                                                                 'action, the '
#                                                                 'stunning '
#                                                                 'cinematography, '
#                                                                 'the use of '
#                                                                 'water as the '
#                                                                 'theme for the '
#                                                                 'movie was an '
#                                                                 'excellent '
#                                                                 'idea. Loved '
#                                                                 'how the movie '
#                                                                 'allowed us to '
#                                                                 'explore '
#                                                                 'different '
#                                                                 'tribes and '
#                                                                 'regions of '
#                                                                 'Pandora, the '
# ...
#                                                                 'forest, water '
#                                                                 'and fire, '
#                                                                 'what could be '
#                                                                 'next.'}},
#                                     {'id': 'UgwsnnhiaJRLGvIySTx4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'avatar '
#                                                                 '1-earth<br>avatar '
#                                                                 '2-water<br>avatar '
#                                                                 '3-fire<br>avatar '
#                                                                 '4-air'}},
#                                     {'id': 'Ugz83V9JpHpaMqq4eD94AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'I knew it. I '
#                                                                 'feel that the '
#                                                                 'Ash People '
#                                                                 'might be a '
#                                                                 'developing '
#                                                                 'antagonist of '
#                                                                 'the film.. '
#                                                                 'can’t wait to '
#                                                                 'see if there '
#                                                                 'are some kind '
#                                                                 'of Air  '
#                                                                 'Navi.'}},
#                                     {'id': 'UgzRATcSiwFvSpoDPbJ4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'Boooriiing'}},
#                                     {'id': 'UgzA-4ke6GUD3LcvKnN4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'It all '
#                                                                 'changed when '
#                                                                 'the fire '
#                                                                 'nation I mean '
#                                                                 'fire Navi '
#                                                                 'attacked'}}]},
#  'mRrKdgpZ6kE_comments': {'etag': 'rqrN4Kz_Wng5D_jKfJ_YTyTWy2k',
#                           'items': [{'id': 'UgzRofq69Q06kzVd7r94AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'So all we '
#                                                                 'have to do is '
#                                                                 'wait for '
#                                                                 'another 14 '
#                                                                 'year&#39;s '
#                                                                 'for the '
#                                                                 'avatar 3..'}},
#                                     {'id': 'UgzCgeMQuZYTfu6vK7B4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'There gona be '
#                                                                 'cool amp '
#                                                                 'suits?'}},
#                                     {'id': 'UgzNFEOLKLOe3za-j6N4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'this is '
#                                                                 'actually '
#                                                                 'good, since '
#                                                                 'this universe '
#                                                                 'is too black '
#                                                                 'and white, '
#                                                                 'portraying '
#                                                                 'the humans as '
#                                                                 'the actual '
#                                                                 'worst, while '
#                                                                 'the Navi as '
#                                                                 'saints, so '
#                                                                 'having an '
#                                                                 'actual tribe '
#                                                                 'or people '
#                                                                 'that do '
#                                                                 'insane or '
#                                                                 'gruesome '
#                                                                 'things would '
#                                                                 'be a breath '
#                                                                 'of fresh air! '
#                                                                 'Also would '
#                                                                 'add a lot of '
#                                                                 'complexity to '
#                                                                 'the Navi '
#                                                                 'species.'}},
#                                     {'id': 'UgzPnVK5IGxfZ18E_Z94AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'Blackamoors '
#                                                                 'vs Muurs If '
#                                                                 'you know you '
#                                                                 'know these '
#                                                                 'movies are a '
#                                                                 'personification '
#                                                                 'of the '
#                                                                 'indigenous '
#                                                                 'Nubians going '
#                                                                 'Against the '
#                                                                 'draconians us '
#                                                                 'vs us . They '
#                                                                 'not like us '
#                                                                 'it’s a civil '
#                                                                 'war'}},
#                                     {'id': 'Ugznhx14d8FM3QevuUd4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'I think I '
#                                                                 'heard '
#                                                                 'somewhere '
#                                                                 'that the Ash '
#                                                                 'People were '
#                                                                 'survivors of '
#                                                                 'the Forest '
#                                                                 'People that '
#                                                                 'were left for '
#                                                                 'dead when the '
#                                                                 'humans '
#                                                                 'destroyed '
#                                                                 'Hometree. So '
#                                                                 'the Ash '
#                                                                 'People have a '
#                                                                 'personal '
#                                                                 'hatred for '
#                                                                 'Jake Sully '
#                                                                 'since the '
#                                                                 'destruction '
#                                                                 'of Hometree '
#                                                                 'was mostly '
#                                                                 'his fault.'}},
#                                     {'id': 'UgxuLV49EXZRbgWoqVF4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'This is what '
#                                                                 'happens when '
#                                                                 'you let '
#                                                                 'insiders in'}},
#                                     {'id': 'UgzYMkwS5Z9fnDfY2814AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'Ok but let’s '
#                                                                 'keep Miles '
#                                                                 'alive thanks '
#                                                                 '😊'}},
#                                     {'id': 'UgyQ239sddflW1yRSyx4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'OMG yet '
#                                                                 'another '
#                                                                 'Avatar '
#                                                                 'movie?<br>Enough '
#                                                                 'already'}},
#                                     {'id': 'UgxYQYdZ_y5Q0pak8g54AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'They probably '
#                                                                 'form the dark '
#                                                                 'side of the '
#                                                                 'moon it’s '
#                                                                 'tidally '
#                                                                 'locked'}},
#                                     {'id': 'Ugxmc9rys--qGM_yWvZ4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'I love this '
#                                                                 'franchise'}}]},
#  'oFErWcXJLdw_comments': {'etag': 'xa8HOUP_SdtX1G-k5nE_iy1FS3Y',
#                           'items': [{'id': 'UgxiKTO7e22egk54Y_p4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'I&#39;ve been '
#                                                                 'riding till I '
#                                                                 'was three and '
#                                                                 'just started '
#                                                                 'English and I '
#                                                                 'already know '
#                                                                 'how to jump'}},
#                                     {'id': 'UgxthSISwODiSRzcLUV4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'The trailer '
#                                                                 'was so good! '
#                                                                 'I was locked '
#                                                                 'in the whole '
#                                                                 'time great '
#                                                                 'job! ❤❤❤❤❤'}},
#                                     {'id': 'Ugx3IlNl00CzHYE6dax4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'You look '
#                                                                 'scary'}},
#                                     {'id': 'Ugzy0hZ0L00iOgfzjs54AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'Dobby is a '
#                                                                 'free elf *18 '
#                                                                 'hours '
#                                                                 'later*Dobby '
#                                                                 'is s free '
#                                                                 'elf!!'}},
#                                     {'id': 'Ugy4kni1dd3qq7c93ml4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'wowwwwwwwwww<br>wwwwwww'}},
#                                     {'id': 'UgwVh0tsQJkBSzmXD514AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': '❤❤❤'}},
#                                     {'id': 'UgyIm3CvZnAxTXNBYn94AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'You should be '
#                                                                 'in an avatar '
#                                                                 'movie'}},
#                                     {'id': 'UgyqrCQZbw3tQ9IMyn54AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'Did you see '
#                                                                 'lexi try to '
#                                                                 'hold andrews '
#                                                                 'hand in the '
#                                                                 'car😂'}},
#                                     {'id': 'UgxSQtO8HWBXXmP3_x14AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'I Love it'}},
#                                     {'id': 'UgzCYg13OEyURxMrAbl4AaABAg',
#                                      'kind': 'youtube#commentThread',
#                                      'snippet': {'textDisplay': 'WOW❤❤❤❤❤ <a '
#                                                                 'href="https://www.youtube.com/watch?v=oFErWcXJLdw&amp;t=534">8:54</a>'}}]}}

# %%
import json

with open('top_10_video_comments.json', 'w') as json_file:
    json.dump(top_video_comments, json_file, indent=4)

# %% [markdown]
# #### d) Function to get  the likes vs views ratio of the top 10 videos obtained in 3.a with the highest comments

# %%
import numpy as np

merged_df = pd.merge(df,top_10_video_ids_and_titles, on='Video ID',how='right')
merged_df[['no_of_views', 'no_of_likes']] = merged_df[['no_of_views', 'no_of_likes']].replace('NA', np.nan).astype(float)

def ratios(df,col1,col2):
    df['likes vs views ratios'] = col1/col2.replace((0,np.inf), np.nan)
    ratios_df = pd.DataFrame({
        'Video ID':df['Video ID'],
        'likes vs views ratios':df['likes vs views ratios'],
        'no_of_comments':df['no_of_comments_x']
    })
    return ratios_df

ratios(merged_df,merged_df['no_of_likes'],merged_df['no_of_views'])
# Out:
#       Video ID  likes vs views ratios  no_of_comments
# 0  d9MyW72ELq0               0.017571           42699
# 1  a8Gx8wiNbs8               0.024084           28934
# 2  bDHD1ueL4a4               0.021230            9731
# 3  RGx8rYbRVR4               0.054284            5202
# 4  doDrnJkgf-s               0.077466            5099
# 5  f5Zx8iPek5I               0.045046            4051
# 6  mRrKdgpZ6kE                    NaN            2300
# 7  PLtgIILX7E8               0.004387            2151
# 8  X8SVkfbt8cs                    NaN            1833
# 9  oFErWcXJLdw               0.017051            1763
